# %% [markdown]
# # Cloud Fund Research Engine
#
# Runs Python heavy work, saves persistent cache/output to Google Drive, and leaves a compact CSV/JSON bridge for ChatGPT.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
PROJECT_DIR = '/content/drive/MyDrive/AI_Fund_Research/code/CLOUD_FUND_RESEARCH_ENGINE_20260807_by_codex'
# %cd $PROJECT_DIR
# !pip -q install -r requirements_colab.txt

# %%
# !python fund_research_engine.py --mode quick-daily --storage-root /content/drive/MyDrive/AI_Fund_Research --top-n 5

# %%
import pandas as pd, json
csv_path = '/content/drive/MyDrive/AI_Fund_Research/output/fund_daily_summary.csv'
json_path = '/content/drive/MyDrive/AI_Fund_Research/output/fund_daily_summary.json'
display(pd.read_csv(csv_path))
print(json_path)
print(json.dumps(json.load(open(json_path)), indent=2)[:2000])
